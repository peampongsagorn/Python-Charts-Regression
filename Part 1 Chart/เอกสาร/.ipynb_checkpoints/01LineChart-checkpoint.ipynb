# %% [markdown]
# #  Line chart

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx',sheet_name='bts')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     217 non-null    datetime64[ns]
#  1   Average daily ridership  217 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 3.5 KB

# %% [markdown]
# ### 1. Single plot

# %% [markdown]
# #### Pandas

# %%
df.plot.line(x='date', y='Average daily ridership',figsize=(12,3),lw=2)
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# #### Matplotlip

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['date'],df['Average daily ridership'], 'r--') # 'r.'กราฟเส้นเป็นจุด , 'r.-'กราฟเป็นจุดมีเส้นเชื่อม 
plt.xlabel('Date')
plt.ylabel('Average daily ridership')
plt.title('BTS')
# Out:
# Text(0.5, 1.0, 'BTS')

# %% [markdown]
# #### Subplot

# %%
x = df['date']
y = df['Average daily ridership']

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r')
plt.subplot(1,2,2)
plt.plot(x, y, 'g');

# %%
plt.subplot(1,2,2)
plt.plot(x, y, 'b');

# %% [markdown]
# ### 2. Using figure object

# %%
# สร้าง figure ว่าง
fig = plt.figure()

# %%
# เพิ่มแกน
axes = fig.add_axes([0, 0, 1, 1]) # left, bottom, width, height (range 0 to 1)

# %%
# Plot on that set of axes
axes.plot(df['date'],df['Average daily ridership'], 'b')

# %%
axes.set_xlabel('Date')
axes.set_ylabel('Average daily ridership')
# Out:
# Text(0, 0.5, 'Average daily ridership')

# %%
axes.set_title('BTS')
# Out:
# Text(0.5, 1.0, 'BTS')

# %%
axes.plot(df['date'],df['Average daily ridership'], 'b')

# %%
fig

# %% [markdown]
# #### เพิ่มกราฟย่อย

# %%
axes2 = fig.add_axes([0.3, 0.6,0.3,0.3]) #เพิ่มกราฟเล็กอีกอันเพื่อดูช่วงย่อย

# %%
# Plot only year 2010 on the second axes
df_2010 = df[ (df['date']<'2011-01-01') & (df['date']>'2009-12-31')]
axes2.plot(df_2010['date'],df_2010['Average daily ridership'], 'r')

# %%
fig

# %% [markdown]
# ### 3. Set figure size

# %%
fig = plt.figure(figsize=(5,2),dpi=100) #dpi ความละเอียดภาพ
axes = fig.add_axes([0, 0, 1, 1])
axes.plot(df['date'],df['Average daily ridership'], 'b')

# %% [markdown]
# ### 4. Subplot เป็นการสร้างกราฟหลายตัวไว้ใน figure เดียว

# %% [markdown]
# #### 1 แถวสร้าง 3 คอลัมน์

# %%
fig, axes = plt.subplots(nrows=1, ncols=3)

# %%
df_2010 = df[ (df['date']<'2011-01-01') & (df['date']>'2009-12-31')]
axes[0].plot(df_2010['date'],df_2010['Average daily ridership'], 'b')

# %%
df_2011 = df[ (df['date']<'2012-01-01') & (df['date']>'2010-12-31')]
axes[1].plot(df_2011['date'],df_2011['Average daily ridership'], 'r')

# %%
df_2012 = df[ (df['date']<'2013-01-01') & (df['date']>'2011-12-31')]
axes[2].plot(df_2012['date'],df_2012['Average daily ridership'], 'y')

# %%
fig.set_size_inches(15,4)
fig.set_dpi(50)
fig

# %% [markdown]
# #### 2 แถว 2 คอลัมน์

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

# %%
df_2010 = df[ (df['date']<'2011-01-01') & (df['date']>'2009-12-31')]
axes[0,0].plot(df_2010['date'],df_2010['Average daily ridership'], 'b')

# %%
df_2011 = df[ (df['date']<'2012-01-01') & (df['date']>'2010-12-31')]
axes[0,1].plot(df_2011['date'],df_2011['Average daily ridership'], 'r')

# %%
df_2012 = df[ (df['date']<'2013-01-01') & (df['date']>'2011-12-31')]
axes[1,0].plot(df_2012['date'],df_2012['Average daily ridership'], 'y')

# %%
df_2013 = df[ (df['date']<'2014-01-01') & (df['date']>'2012-12-31')]
axes[1,1].plot(df_2013['date'],df_2013['Average daily ridership'], 'g')

# %%
fig.set_size_inches(15,4)
fig.set_dpi(70)
fig

# %% [markdown]
# ### 5. Plot multi-line in one graph

# %%
fig = plt.figure()

# %%
axes = fig.add_axes([0,0,1,1])

# %%
df_2015 = df[ (df['date']<'2016-01-01') & (df['date']>'2014-12-31')]
axes.plot(df_2015['date'],df_2015['Average daily ridership'])

# %%
df_2016 = df[ (df['date']<'2017-01-01') & (df['date']>'2015-12-31')]
axes.plot(df_2016['date'],df_2016['Average daily ridership'])

# %%
fig

# %% [markdown]
# #### Compare ridership in each month จากกราฟก่อนหน้า ไม่ได้เป็นการเปรียบเทียบกันของเดือนในปีที่ต่างกันแต่จะเป็นช่วงที่ต่อกัน

# %%
fig = plt.figure()

# %%
axes = fig.add_axes([0,0,1,1])

# %%
df_2015 = df[ (df['date']<'2016-01-01') & (df['date']>'2014-12-31')]

# %%
df_2015['month'] = df_2015['date'].dt.month_name()
# Out:
# C:\Users\Notebook\AppData\Local\Temp\ipykernel_11176\1660727743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2015['month'] = df_2015['date'].dt.month_name()

# %%
axes.plot(df_2015['month'],df_2015['Average daily ridership'],label='2015')

# %%
df_2016 = df[ (df['date']<'2017-01-01') & (df['date']>'2015-12-31')]
df_2016['month'] = df_2016['date'].dt.month_name()
axes.plot(df_2016['month'],df_2016['Average daily ridership'],label='2016')
# Out:
# C:\Users\Notebook\AppData\Local\Temp\ipykernel_11176\650806120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016['month'] = df_2016['date'].dt.month_name()

# %%
axes.legend() #ใช้นิยามข้อมูลว่าแต่ละเส้นคืออะไร

# %%
fig.set_size_inches(10,3)
fig.set_dpi(100)

# %%
fig

# %% [markdown]
# ### 5. Define plot range

# %%
import numpy as np
x = np.linspace(0, 5, 11) #เริ่ม 0 จบ 5 ให้ได้ 11 ตัว

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")
# Out:
# Text(0.5, 1.0, 'default axes ranges')

# %%
axes[1].plot(x, x**2, x, x**3)
axes[1].set_ylim([0, 60])
axes[1].set_xlim([2, 5])
axes[1].set_title("custom axes range");

# %%
fig

# %% [markdown]
# ### 6. Color, line width, line style

# %%
import numpy as np
x = np.linspace(0, 5, 11)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
